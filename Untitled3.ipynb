# %%
# test all_signals

# %%
# %run all_signals_model_priority_config.py --source-file "signals_h5ensemble/signals_20260810.csv"  \
--audit-file test.csv --start-date 20260809 --end-date 20260812 --model-name model_h5ensemble
# Out:
# Audit file saved: test.csv
# Source file: signals_h5ensemble/signals_20260810.csv
# Model name: model_h5ensemble
# Filtered source rows: 8
# Updated audit keys: 0
# Appended audit keys: 8
# Final audit rows: 14
# Source date range used: 20260810 to 20260810

# %%
# %run all_signals_model_priority_config.py \
--source-file "signals_h5ensemble/signals_20260810.csv"  \
--audit-file h5ensemble.csv \
--start-date 20260809 \
--end-date 20260812 \
--model-name model_h5ensemble
# Out:
# Audit file saved: test.csv
# Source file: signals_h5ensemble/signals_20260810.csv
# Model name: model_h5ensemble
# Filtered source rows: 8
# Updated audit keys: 8
# Appended audit keys: 0
# Final audit rows: 14
# Source date range used: 20260810 to 20260810

# %%
# %run all_signals_model_priority_config.py \
--audit-file h5priority.csv \
--start-date 20260501 \
--end-date 20260815 \
--model-name h5m80d50_priority
# Out:
# ================================================================================
# Model:        h5m80d50_priority
# Signal dir:   signals_h5priority
# Date range:   20260501 -> 20260815
# Files found:  72
# ================================================================================
#
# [1/72] 20260506  signals_h5m80d50_priority_20260506.csv
#     rows=3 updated=0 appended=3
#
# [2/72] 20260507  signals_h5m80d50_priority_20260507.csv
#     rows=3 updated=0 appended=3
#
# [3/72] 20260508  signals_h5m80d50_priority_20260508.csv
#     rows=3 updated=0 appended=3
#
# [4/72] 20260511  signals_h5m80d50_priority_20260511.csv
#     rows=3 updated=0 appended=3
#
# [5/72] 20260512  signals_h5m80d50_priority_20260512.csv
#     rows=3 updated=0 appended=3
#
# [6/72] 20260513  signals_h5m80d50_priority_20260513.csv
#     rows=3 updated=0 appended=3
#
# [7/72] 20260514  signals_h5m80d50_priority_20260514.csv
#     rows=3 updated=0 appended=3
#
# [8/72] 20260515  signals_h5m80d50_priority_20260515.csv
#     rows=4 updated=0 appended=4
#
# [9/72] 20260518  signals_h5m80d50_priority_20260518.csv
#     rows=3 updated=0 appended=3
#
# [10/72] 20260519  signals_h5m80d50_priority_20260519.csv
#     rows=3 updated=0 appended=3
#
# [11/72] 20260520  signals_h5m80d50_priority_20260520.csv
#     rows=3 updated=0 appended=3
#
# [12/72] 20260521  signals_h5m80d50_priority_20260521.csv
#     rows=3 updated=0 appended=3
#
# [13/72] 20260522  signals_h5m80d50_priority_20260522.csv
#     rows=3 updated=0 appended=3
#
# [14/72] 20260525  signals_h5m80d50_priority_20260525.csv
#     rows=3 updated=0 appended=3
#
# [15/72] 20260526  signals_h5m80d50_priority_20260526.csv
#     rows=3 updated=0 appended=3
#
# [16/72] 20260527  signals_h5m80d50_priority_20260527.csv
#     rows=3 updated=0 appended=3
#
# [17/72] 20260528  signals_h5m80d50_priority_20260528.csv
#     rows=3 updated=0 appended=3
#
# [18/72] 20260529  signals_h5m80d50_priority_20260529.csv
#     rows=3 updated=0 appended=3
#
# [19/72] 20260601  signals_h5m80d50_priority_20260601.csv
#     rows=3 updated=0 appended=3
#
# [20/72] 20260602  signals_h5m80d50_priority_20260602.csv
#     rows=3 updated=0 appended=3
#
# [21/72] 20260603  signals_h5m80d50_priority_20260603.csv
#     rows=3 updated=0 appended=3
#
# [22/72] 20260604  signals_h5m80d50_priority_20260604.csv
#     rows=3 updated=0 appended=3
#
# [23/72] 20260605  signals_h5m80d50_priority_20260605.csv
#     rows=3 updated=0 appended=3
#
# [24/72] 20260608  signals_h5m80d50_priority_20260608.csv
#     rows=3 updated=0 appended=3
#
# [25/72] 20260609  signals_h5m80d50_priority_20260609.csv
#     rows=3 updated=0 appended=3
#
# [26/72] 20260610  signals_h5m80d50_priority_20260610.csv
#     rows=4 updated=0 appended=4
#
# [27/72] 20260611  signals_h5m80d50_priority_20260611.csv
#     rows=3 updated=0 appended=3
#
# [28/72] 20260612  signals_h5m80d50_priority_20260612.csv
#     rows=3 updated=0 appended=3
#
# [29/72] 20260615  signals_h5m80d50_priority_20260615.csv
#     rows=3 updated=0 appended=3
#
# [30/72] 20260616  signals_h5m80d50_priority_20260616.csv
#     rows=3 updated=0 appended=3
#
# [31/72] 20260617  signals_h5m80d50_priority_20260617.csv
#     rows=3 updated=0 appended=3
#
# [32/72] 20260618  signals_h5m80d50_priority_20260618.csv
#     rows=3 updated=0 appended=3
#
# [33/72] 20260622  signals_h5m80d50_priority_20260622.csv
#     rows=3 updated=0 appended=3
#
# [34/72] 20260623  signals_h5m80d50_priority_20260623.csv
#     rows=3 updated=0 appended=3
#
# [35/72] 20260624  signals_h5m80d50_priority_20260624.csv
#     rows=3 updated=0 appended=3
#
# [36/72] 20260625  signals_h5m80d50_priority_20260625.csv
#     rows=3 updated=0 appended=3
#
# [37/72] 20260626  signals_h5m80d50_priority_20260626.csv
#     rows=3 updated=0 appended=3
#
# [38/72] 20260629  signals_h5m80d50_priority_20260629.csv
#     rows=3 updated=0 appended=3
#
# [39/72] 20260630  signals_h5m80d50_priority_20260630.csv
#     rows=3 updated=0 appended=3
#
# [40/72] 20260701  signals_h5m80d50_priority_20260701.csv
#     rows=4 updated=4 appended=0
#
# [41/72] 20260702  signals_h5m80d50_priority_20260702.csv
#     rows=3 updated=3 appended=0
#
# [42/72] 20260703  signals_h5m80d50_priority_20260703.csv
#     rows=3 updated=3 appended=0
#
# [43/72] 20260706  signals_h5m80d50_priority_20260706.csv
#     rows=3 updated=3 appended=0
#
# [44/72] 20260707  signals_h5m80d50_priority_20260707.csv
#     rows=4 updated=4 appended=0
#
# [45/72] 20260708  signals_h5m80d50_priority_20260708.csv
#     rows=3 updated=3 appended=0
#
# [46/72] 20260709  signals_h5m80d50_priority_20260709.csv
#     rows=3 updated=3 appended=0
#
# [47/72] 20260710  signals_h5m80d50_priority_20260710.csv
#     rows=4 updated=4 appended=0
#
# [48/72] 20260713  signals_h5m80d50_priority_20260713.csv
#     rows=3 updated=3 appended=0
#
# [49/72] 20260714  signals_h5m80d50_priority_20260714.csv
#     rows=3 updated=3 appended=0
#
# [50/72] 20260715  signals_h5m80d50_priority_20260715.csv
#     rows=3 updated=3 appended=0
#
# [51/72] 20260716  signals_h5m80d50_priority_20260716.csv
#     rows=3 updated=3 appended=0
#
# [52/72] 20260717  signals_h5m80d50_priority_20260717.csv
#     rows=3 updated=3 appended=0
#
# [53/72] 20260720  signals_h5m80d50_priority_20260720.csv
#     rows=3 updated=3 appended=0
#
# [54/72] 20260721  signals_h5m80d50_priority_20260721.csv
#     rows=3 updated=3 appended=0
#
# [55/72] 20260722  signals_h5m80d50_priority_20260722.csv
#     rows=3 updated=3 appended=0
#
# [56/72] 20260723  signals_h5m80d50_priority_20260723.csv
#     rows=3 updated=3 appended=0
#
# [57/72] 20260724  signals_h5m80d50_priority_20260724.csv
#     rows=3 updated=3 appended=0
#
# [58/72] 20260727  signals_h5m80d50_priority_20260727.csv
#     rows=3 updated=3 appended=0
#
# [59/72] 20260728  signals_h5m80d50_priority_20260728.csv
#     rows=3 updated=3 appended=0
#
# [60/72] 20260729  signals_h5m80d50_priority_20260729.csv
#     rows=3 updated=3 appended=0
#
# [61/72] 20260730  signals_h5m80d50_priority_20260730.csv
#     rows=4 updated=4 appended=0
#
# [62/72] 20260731  signals_h5m80d50_priority_20260731.csv
#     rows=3 updated=3 appended=0
#
# [63/72] 20260803  signals_h5m80d50_priority_20260803.csv
#     rows=3 updated=3 appended=0
#
# [64/72] 20260804  signals_h5m80d50_priority_20260804.csv
#     rows=3 updated=3 appended=0
#
# [65/72] 20260805  signals_h5m80d50_priority_20260805.csv
#     rows=3 updated=3 appended=0
#
# [66/72] 20260806  signals_h5m80d50_priority_20260806.csv
#     rows=3 updated=3 appended=0
#
# [67/72] 20260807  signals_h5m80d50_priority_20260807.csv
#     rows=3 updated=3 appended=0
#
# [68/72] 20260810  signals_h5m80d50_priority_20260810.csv
#     rows=3 updated=3 appended=0
#
# [69/72] 20260811  signals_h5m80d50_priority_20260811.csv
#     rows=3 updated=3 appended=0
#
# [70/72] 20260812  signals_h5m80d50_priority_20260812.csv
#     rows=3 updated=3 appended=0
#
# [71/72] 20260813  signals_h5m80d50_priority_20260813.csv
#     rows=3 updated=3 appended=0
#
# [72/72] 20260814  signals_h5m80d50_priority_20260814.csv
#     rows=3 updated=2 appended=1
#
# ================================================================================
# Files processed: 72
# Source rows:     222
# Rows updated:    102
# Rows appended:   120
# Audit rows:      223
# Saved:           h5priority.csv
# ================================================================================

# %%
# %run fill_signals_targets.py --signals h5priority.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h5priority_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=223 already_filled=0
# [result] newly_sold=211 open_updated=8 unresolved=4
# [write] h5priority_target.csv

# %%
# %run all_signals_model_priority_config.py \
--audit-file h2dual.csv \
--start-date 20260501 \
--end-date 20260815 \
--model-name h2m80d50_dual
# Out:
# ================================================================================
# Model:        h2m80d50_dual
# Signal dir:   signals_h2dual
# Date range:   20260501 -> 20260815
# Files found:  72
# ================================================================================
#
# [1/72] 20260506  signals_20260506.csv
#     rows=0 updated=0 appended=0
#
# [2/72] 20260507  signals_20260507.csv
#     rows=0 updated=0 appended=0
#
# [3/72] 20260508  signals_20260508.csv
#     rows=1 updated=0 appended=1
#
# [4/72] 20260511  signals_20260511.csv
#     rows=1 updated=0 appended=1
#
# [5/72] 20260512  signals_20260512.csv
#     rows=1 updated=0 appended=1
#
# [6/72] 20260513  signals_20260513.csv
#     rows=0 updated=0 appended=0
#
# [7/72] 20260514  signals_20260514.csv
#     rows=0 updated=0 appended=0
#
# [8/72] 20260515  signals_20260515.csv
#     rows=2 updated=0 appended=2
#
# [9/72] 20260518  signals_20260518.csv
#     rows=2 updated=0 appended=2
#
# [10/72] 20260519  signals_20260519.csv
#     rows=0 updated=0 appended=0
#
# [11/72] 20260520  signals_20260520.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Downloads/01-Stock/h5m80d50/all_signals_model_priority_config.py:363
#     353     process_files(
#     354         audit_file=args.audit_file,
#     355         model_name=args.model_name,
#    (...)    358         signal_dir_override=args.signal_dir,
#     359     )
#     362 if __name__ == "__main__":
# --> 363     main()
#
# File ~/Downloads/01-Stock/h5m80d50/all_signals_model_priority_config.py:353, in main()
#     351 def main() -> None:
#     352     args = parse_args()
# --> 353     process_files(
#     354         audit_file=args.audit_file,
#     355         model_name=args.model_name,
#     356         start_date=args.start_date,
#     357         end_date=args.end_date,
#     358         signal_dir_override=args.signal_dir,
#     359     )
#
# File ~/Downloads/01-Stock/h5m80d50/all_signals_model_priority_config.py:294, in process_files(audit_file, model_name, start_date, end_date, signal_dir_override)
#     292 for index, (file_date, source_file) in enumerate(signal_files, start=1):
#     293     print(f"\n[{index}/{len(signal_files)}] {file_date}  {source_file.name}")
# --> 294     source_data = prepare_source_data(
#     295         source_data=read_data_file(source_file),
#     296         model_name=model_name,
#     297         file_date=file_date,
#     298         source_file=source_file,
#     299     )
#     300     audit_data, updated_count, appended_count = merge_source_into_audit(
#     301         audit_data=audit_data,
#     302         source_data=source_data,
#     303     )
#     304     total_source_rows += len(source_data)
#
# File ~/Downloads/01-Stock/h5m80d50/all_signals_model_priority_config.py:157, in prepare_source_data(source_data, model_name, file_date, source_file)
#     149 if unknown_mask.any():
#     150     unknown_values = sorted(
#     151         data.loc[unknown_mask, "priority_name"]
#     152         .dropna()
#    (...)    155         .tolist()
#     156     )
# --> 157     raise ValueError(
#     158         f"{source_file}: model {model_name!r} contains priority names "
#     159         f"not present in priority_mapping: {unknown_values}"
#     160     )
#     162 data = data[NEW_ROW_COLUMNS].copy()
#     163 duplicate_mask = data.duplicated(subset=KEY_COLUMNS, keep="first")
#
# ValueError: signals_h2dual/signals_20260520.csv: model 'h2m80d50_dual' contains priority names not present in priority_mapping: ['layer2_m3_only']

# %%
# %run fill_signals_targets.py --signals h2dual.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h2dual_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=87 already_filled=0
# [result] newly_sold=78 open_updated=7 unresolved=2
# [write] h2dual_target.csv

# %%
# %run all_signals_model_priority_config.py \
--audit-file h5ensemble.csv \
--start-date 20260701 \
--end-date 20260814 \
--model-name h5m80d50_ensemble
# Out:
# ================================================================================
# Model:        h5m80d50_ensemble
# Signal dir:   signals_h5ensemble
# Date range:   20260701 -> 20260814
# Files found:  33
# ================================================================================
# Audit file does not exist. A new file will be created: h5ensemble.csv
#
# [1/33] 20260701  signals_20260701.csv
#     rows=5 updated=0 appended=5
#
# [2/33] 20260702  signals_20260702.csv
#     rows=5 updated=0 appended=5
#
# [3/33] 20260703  signals_20260703.csv
#     rows=6 updated=0 appended=6
#
# [4/33] 20260706  signals_20260706.csv
#     rows=5 updated=0 appended=5
#
# [5/33] 20260707  signals_20260707.csv
#     rows=6 updated=0 appended=6
#
# [6/33] 20260708  signals_20260708.csv
#     rows=7 updated=0 appended=7
#
# [7/33] 20260709  signals_20260709.csv
#     rows=7 updated=0 appended=7
#
# [8/33] 20260710  signals_20260710.csv
#     rows=8 updated=0 appended=8
#
# [9/33] 20260713  signals_20260713.csv
#     rows=7 updated=0 appended=7
#
# [10/33] 20260714  signals_20260714.csv
#     rows=8 updated=0 appended=8
#
# [11/33] 20260715  signals_20260715.csv
#     rows=5 updated=0 appended=5
#
# [12/33] 20260716  signals_20260716.csv
#     rows=5 updated=0 appended=5
#
# [13/33] 20260717  signals_20260717.csv
#     rows=5 updated=0 appended=5
#
# [14/33] 20260720  signals_20260720.csv
#     rows=5 updated=0 appended=5
#
# [15/33] 20260721  signals_20260721.csv
#     rows=7 updated=0 appended=7
#
# [16/33] 20260722  signals_20260722.csv
#     rows=6 updated=0 appended=6
#
# [17/33] 20260723  signals_20260723.csv
#     rows=7 updated=0 appended=7
#
# [18/33] 20260724  signals_20260724.csv
#     rows=6 updated=0 appended=6
#
# [19/33] 20260727  signals_20260727.csv
#     rows=5 updated=0 appended=5
#
# [20/33] 20260728  signals_20260728.csv
#     rows=5 updated=0 appended=5
#
# [21/33] 20260729  signals_20260729.csv
#     rows=6 updated=0 appended=6
#
# [22/33] 20260730  signals_20260730.csv
#     rows=6 updated=0 appended=6
#
# [23/33] 20260731  signals_20260731.csv
#     rows=8 updated=0 appended=8
#
# [24/33] 20260803  signals_20260803.csv
#     rows=7 updated=0 appended=7
#
# [25/33] 20260804  signals_20260804.csv
#     rows=7 updated=0 appended=7
#
# [26/33] 20260805  signals_20260805.csv
#     rows=7 updated=0 appended=7
#
# [27/33] 20260806  signals_20260806.csv
#     rows=8 updated=0 appended=8
#
# [28/33] 20260807  signals_20260807.csv
#     rows=8 updated=0 appended=8
#
# [29/33] 20260810  signals_20260810.csv
#     rows=8 updated=0 appended=8
#
# [30/33] 20260811  signals_20260811.csv
#     rows=6 updated=0 appended=6
#
# [31/33] 20260812  signals_20260812.csv
#     rows=7 updated=0 appended=7
#
# [32/33] 20260813  signals_20260813.csv
#     rows=6 updated=0 appended=6
#
# [33/33] 20260814  signals_20260814.csv
#     rows=6 updated=0 appended=6
#
# ================================================================================
# Files processed: 33
# Source rows:     210
# Rows updated:    0
# Rows appended:   210
# Audit rows:      210
# Saved:           h5ensemble.csv
# ================================================================================

# %%
# %run fill_signals_targets.py --signals h5ensemble.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h5ensemble_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=210 already_filled=0
# [result] newly_sold=183 open_updated=21 unresolved=6
# [write] h5ensemble_target.csv

# %%
# %run fill_signals_targets.py --signals h2dual.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h2dual_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=87 already_filled=0
# [result] newly_sold=78 open_updated=7 unresolved=2
# [write] h2dual_target.csv
