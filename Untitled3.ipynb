# %%
# test all_signals

# %%
# %run all_signals_model_priority_config.py --source-file "signals_h5ensemble/signals_20260810.csv"  \
--audit-file test.csv --start-date 20260809 --end-date 20260812 --model-name model_h5ensemble
# Out:
# Audit file saved: test.csv
# Source file: signals_h5ensemble/signals_20260810.csv
# Model name: model_h5ensemble
# Filtered source rows: 8
# Updated audit keys: 0
# Appended audit keys: 8
# Final audit rows: 14
# Source date range used: 20260810 to 20260810

# %%
# %run all_signals_model_priority_config.py \
--source-file "signals_h5ensemble/signals_20260810.csv"  \
--audit-file h5ensemble.csv \
--start-date 20260809 \
--end-date 20260812 \
--model-name model_h5ensemble
# Out:
# Audit file saved: test.csv
# Source file: signals_h5ensemble/signals_20260810.csv
# Model name: model_h5ensemble
# Filtered source rows: 8
# Updated audit keys: 8
# Appended audit keys: 0
# Final audit rows: 14
# Source date range used: 20260810 to 20260810

# %%
# %run all_signals_model_priority_config.py \
--audit-file /home/mark/dev/csi1500/h3consensus.csv \
--start-date 20260104 \
--end-date 20260909 \
--model-name h3m55d15_consensus
# Out:
# None
# ...
# Model:        h3m55d15_consensus
# Signal dir:   signals_h3consensus
# Date range:   20260104 -> 20260909
# Files found:  161
# ...
# Audit file does not exist. A new file will be created: /home/mark/dev/csi1500/h3consensus.csv
#
# [1/161] 20260105  signals_20260105.csv
#     rows=3 updated=0 appended=3
#
# [2/161] 20260106  signals_20260106.csv
#     rows=3 updated=0 appended=3
#
# [3/161] 20260107  signals_20260107.csv
#     rows=2 updated=0 appended=2
#
# [4/161] 20260108  signals_20260108.csv
#     rows=3 updated=0 appended=3
#
# [5/161] 20260109  signals_20260109.csv
#     rows=0 updated=0 appended=0
#
# [6/161] 20260112  signals_20260112.csv
#     rows=0 updated=0 appended=0
#
# [7/161] 20260113  signals_20260113.csv
#     rows=3 updated=0 appended=3
#
# [8/161] 20260114  signals_20260114.csv
#     rows=3 updated=0 appended=3
#
# [9/161] 20260115  signals_20260115.csv
#     rows=3 updated=0 appended=3
#
# [10/161] 20260116  signals_20260116.csv
# ...

# %%
# %run all_signals_model_priority_config.py \
--audit-file /home/mark/dev/csi1500/h5direction_full.csv \
--start-date 20220104 \
--end-date 20260901 \
--model-name h5m80d50_direction \
--signal-dir /home/mark/dev/csi1500/signals_direction_20220104_20260901
# Out:
# /home/mark/dev/csi1500/signals_direction_20220104_20260901
# ...
# Model:        h5m80d50_direction
# Signal dir:   /home/mark/dev/csi1500/signals_direction_20220104_20260901
# Date range:   20220104 -> 20260901
# Files found:  1130
# ...
#
# [1/1130] 20220104  signals_20220104.csv
#     rows=3 updated=3 appended=0
#
# [2/1130] 20220105  signals_20220105.csv
#     rows=3 updated=2 appended=1
#
# [3/1130] 20220106  signals_20220106.csv
#     rows=3 updated=1 appended=2
#
# [4/1130] 20220107  signals_20220107.csv
#     rows=3 updated=3 appended=0
#
# [5/1130] 20220110  signals_20220110.csv
#     rows=3 updated=2 appended=1
#
# [6/1130] 20220111  signals_20220111.csv
#     rows=3 updated=3 appended=0
#
# [7/1130] 20220112  signals_20220112.csv
#     rows=3 updated=2 appended=1
#
# [8/1130] 20220113  signals_20220113.csv
#     rows=3 updated=2 appended=1
#
# [9/1130] 20220114  signals_20220114.csv
#     rows=2 updated=1 appended=1
#
# [10/1130] 20220117  signals_20220117.csv
# ...

# %%
# %run all_signals_model_priority_config.py \
--audit-file /home/mark/dev/csi1500/h5priority.csv \
--start-date 20220104 \
--end-date 20260901 \
--model-name h5m80d50_priority \
--signal-dir /home/mark/dev/csi1500/signals_priority_20220104_20260901
# Out:
# /home/mark/dev/csi1500/signals_priority_20220104_20260901
# ...
# Model:        h5m80d50_priority
# Signal dir:   /home/mark/dev/csi1500/signals_priority_20220104_20260901
# Date range:   20220104 -> 20260901
# Files found:  1130
# ...
# Audit file does not exist. A new file will be created: /home/mark/dev/csi1500/h5priority.csv
#
# [1/1130] 20220104  signals_h5m80d50_priority_20220104.csv
#     rows=3 updated=0 appended=3
#
# [2/1130] 20220105  signals_h5m80d50_priority_20220105.csv
#     rows=3 updated=0 appended=3
#
# [3/1130] 20220106  signals_h5m80d50_priority_20220106.csv
#     rows=3 updated=0 appended=3
#
# [4/1130] 20220107  signals_h5m80d50_priority_20220107.csv
#     rows=3 updated=0 appended=3
#
# [5/1130] 20220110  signals_h5m80d50_priority_20220110.csv
#     rows=3 updated=0 appended=3
#
# [6/1130] 20220111  signals_h5m80d50_priority_20220111.csv
#     rows=3 updated=0 appended=3
#
# [7/1130] 20220112  signals_h5m80d50_priority_20220112.csv
#     rows=3 updated=0 appended=3
#
# ...

# %%
# %run all_signals_model_priority_config.py \
--audit-file /home/mark/dev/csi1500/h3dual_full.csv \
--start-date 20220104 \
--end-date 20260901 \
--model-name h3m55d15_dual \
--signal-dir /home/mark/dev/csi1500/signals_dual_20220104_20260901
# Out:
# /home/mark/dev/csi1500/signals_dual_20220104_20260901
# ...
# Model:        h3m55d15_dual
# Signal dir:   /home/mark/dev/csi1500/signals_dual_20220104_20260901
# Date range:   20220104 -> 20260901
# Files found:  1130
# ...
# Audit file does not exist. A new file will be created: /home/mark/dev/csi1500/h3dual_full.csv
#
# [1/1130] 20220104  signals_20220104.csv
#     rows=1 updated=0 appended=1
#
# [2/1130] 20220105  signals_20220105.csv
#     rows=0 updated=0 appended=0
#
# [3/1130] 20220106  signals_20220106.csv
#     rows=0 updated=0 appended=0
#
# [4/1130] 20220107  signals_20220107.csv
#     rows=0 updated=0 appended=0
#
# [5/1130] 20220110  signals_20220110.csv
#     rows=0 updated=0 appended=0
#
# [6/1130] 20220111  signals_20220111.csv
#     rows=0 updated=0 appended=0
#
# [7/1130] 20220112  signals_20220112.csv
#     rows=0 updated=0 appended=0
#
# [8/1130] 20220113  signals_20220113.csv
#     rows=2 updated=0 appended=2
#
# [9/1130] 20220114  signals_20220114.csv
# ...

# %%
# %run all_signals_model_priority_config.py \
--audit-file /home/mark/dev/csi1500/h5ensemble_full.csv \
--start-date 20220104 \
--end-date 20260901 \
--model-name h5m80d50_ensemble \
--signal-dir /home/mark/dev/csi1500/signals_ensemble_20220104_20260901
# Out:
# /home/mark/dev/csi1500/signals_ensemble_20220104_20260901
# ...
# Model:        h5m80d50_ensemble
# Signal dir:   /home/mark/dev/csi1500/signals_ensemble_20220104_20260901
# Date range:   20220104 -> 20260901
# Files found:  1130
# ...
# Audit file does not exist. A new file will be created: /home/mark/dev/csi1500/h5ensemble_full.csv
#
# [1/1130] 20220104  signals_20220104.csv
#     rows=5 updated=0 appended=5
#
# [2/1130] 20220105  signals_20220105.csv
#     rows=5 updated=0 appended=5
#
# [3/1130] 20220106  signals_20220106.csv
#     rows=5 updated=0 appended=5
#
# [4/1130] 20220107  signals_20220107.csv
#     rows=5 updated=0 appended=5
#
# [5/1130] 20220110  signals_20220110.csv
#     rows=5 updated=0 appended=5
#
# [6/1130] 20220111  signals_20220111.csv
#     rows=5 updated=0 appended=5
#
# [7/1130] 20220112  signals_20220112.csv
#     rows=6 updated=0 appended=6
#
# [8/1130] 20220113  signals_20220113.csv
#     rows=6 updated=0 appended=6
#
# [9/1130] 20220114  signals_20220114.csv
# ...

# %%
# %run fill_signals_targets.py --signals /home/mark/dev/csi1500/h3consensus.csv \
--stock-dir /home/mark/dev/csi1500/processed/daily/merged \
--benchmark /home/mark/dev/csi1500/processed/index/csi1500_custom_index.csv \
--out /home/mark/dev/csi1500/h3consensus_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=319 already_filled=0
# [result] newly_sold=313 open_updated=3 unresolved=3
# [write] /home/mark/dev/csi1500/h3consensus_target.csv

# %%
# %run fill_signals_targets.py --signals /home/mark/dev/csi1500/h3dual_full.csv \
--stock-dir /home/mark/dev/csi1500/processed/daily/merged \
--benchmark /home/mark/dev/csi1500/processed/index/csi1500_custom_index.csv \
--out /home/mark/dev/csi1500/h3dual_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [progress] checked=500/2568 sold=493 open_updated=2 unresolved=5
# [progress] checked=1000/2568 sold=993 open_updated=2 unresolved=5
# [progress] checked=1500/2568 sold=1493 open_updated=2 unresolved=5
# [progress] checked=2000/2568 sold=1993 open_updated=2 unresolved=5
# [progress] checked=2500/2568 sold=2493 open_updated=2 unresolved=5
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=2568 already_filled=0
# [result] newly_sold=2561 open_updated=2 unresolved=5
# [write] /home/mark/dev/csi1500/h3consensus_target.csv

# %%
# %run fill_signals_targets.py --signals /home/mark/dev/csi1500/h5ensemble_full.csv \
--stock-dir /home/mark/dev/csi1500/processed/daily/merged \
--benchmark /home/mark/dev/csi1500/processed/index/csi1500_custom_index.csv \
--out /home/mark/dev/csi1500/h5ensemble_2022_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [progress] checked=500/6313 sold=483 open_updated=12 unresolved=5
# [progress] checked=1000/6313 sold=983 open_updated=12 unresolved=5
# [progress] checked=1500/6313 sold=1483 open_updated=12 unresolved=5
# [progress] checked=2000/6313 sold=1983 open_updated=12 unresolved=5
# [progress] checked=2500/6313 sold=2483 open_updated=12 unresolved=5
# [progress] checked=3000/6313 sold=2983 open_updated=12 unresolved=5
# [progress] checked=3500/6313 sold=3483 open_updated=12 unresolved=5
# [progress] checked=4000/6313 sold=3983 open_updated=12 unresolved=5
# [progress] checked=4500/6313 sold=4483 open_updated=12 unresolved=5
# [progress] checked=5000/6313 sold=4983 open_updated=12 unresolved=5
# [progress] checked=5500/6313 sold=5483 open_updated=12 unresolved=5
# [progress] checked=6000/6313 sold=5983 open_updated=12 unresolved=5
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=6313 already_filled=0
# [result] newly_sold=6296 open_updated=12 unresolved=5
# ...

# %%
# %run fill_signals_targets.py --signals /home/mark/dev/csi1500/h5priority_all.csv \
--stock-dir /home/mark/dev/csi1500/processed/daily/merged \
--benchmark /home/mark/dev/csi1500/processed/index/csi1500_custom_index.csv \
--out /home/mark/dev/csi1500/h5direction_2022_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [progress] checked=500/3542 sold=486 open_updated=11 unresolved=3
# [progress] checked=1000/3542 sold=986 open_updated=11 unresolved=3
# [progress] checked=1500/3542 sold=1486 open_updated=11 unresolved=3
# [progress] checked=2000/3542 sold=1986 open_updated=11 unresolved=3
# [progress] checked=2500/3542 sold=2486 open_updated=11 unresolved=3
# [progress] checked=3000/3542 sold=2986 open_updated=11 unresolved=3
# [progress] checked=3500/3542 sold=3486 open_updated=11 unresolved=3
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=3542 already_filled=0
# [result] newly_sold=3528 open_updated=11 unresolved=3
# [write] /home/mark/dev/csi1500/h5direction_2022_target.csv

# %%
# %run fill_signals_targets.py --signals h5direction_all.csv \
--stock-dir /home/mark/dev/csi1500/processed/daily/merged \
--benchmark /home/mark/dev/csi1500/processed/index/csi1500_custom_index.csv \
--out h5direction_all_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [progress] checked=500/3156 sold=422 open_updated=3 unresolved=75
# [progress] checked=1000/3156 sold=922 open_updated=3 unresolved=75
# [progress] checked=1500/3156 sold=1422 open_updated=3 unresolved=75
# [progress] checked=2000/3156 sold=1922 open_updated=3 unresolved=75
# [progress] checked=2500/3156 sold=2422 open_updated=3 unresolved=75
# [progress] checked=3000/3156 sold=2922 open_updated=3 unresolved=75
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=3156 already_filled=0
# [result] newly_sold=3078 open_updated=3 unresolved=75
# [write] h5direction_all_target.csv

# %%
# %run fill_signals_targets.py --signals h5direction_all.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h5direction_all_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [progress] checked=500/3156 sold=493 open_updated=4 unresolved=3
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=3156 already_filled=0
# [result] newly_sold=666 open_updated=4 unresolved=2486
# [write] h5direction_all_target.csv

# %%
# %run all_signals_model_priority_config.py \
--audit-file h2dual.csv \
--start-date 20260106 \
--end-date 20260903 \
--model-name h2m80d50_dual
# Out:
# ...
# Model:        h2m80d50_dual
# Signal dir:   signals_h2dual
# Date range:   20260106 -> 20260903
# Files found:  162
# ...
#
# [1/162] 20260106  signals_20260106.csv
#     rows=1 updated=1 appended=0
#
# [2/162] 20260107  signals_20260107.csv
#     rows=1 updated=1 appended=0
#
# [3/162] 20260108  signals_20260108.csv
#     rows=0 updated=0 appended=0
#
# [4/162] 20260109  signals_20260109.csv
#     rows=0 updated=0 appended=0
#
# [5/162] 20260112  signals_20260112.csv
#     rows=0 updated=0 appended=0
#
# [6/162] 20260113  signals_20260113.csv
#     rows=0 updated=0 appended=0
#
# [7/162] 20260114  signals_20260114.csv
#     rows=1 updated=1 appended=0
#
# [8/162] 20260115  signals_20260115.csv
#     rows=1 updated=1 appended=0
#
# [9/162] 20260116  signals_20260116.csv
#     rows=0 updated=0 appended=0
#
# [10/162] 20260119  signals_20260119.csv
#     rows=1 updated=1 appended=0
#
# [11/162] 20260120  signals_20260120.csv
#     rows=0 updated=0 appended=0
#
# ...

# %%
# %run fill_signals_targets.py --signals h3dual.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h3dual_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=260 already_filled=0
# [result] newly_sold=244 open_updated=9 unresolved=7
# [write] h3dual_target.csv

# %%
# %run fill_signals_targets.py --signals h2dual.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h2dual_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [progress] checked=500/520 sold=472 open_updated=14 unresolved=14
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=520 already_filled=0
# [result] newly_sold=492 open_updated=14 unresolved=14
# [write] h2dual_target.csv

# %%
# %run all_signals_model_priority_config.py \
--audit-file h5ensemble.csv \
--start-date 20260815 \
--end-date 20260821 \
--model-name h5m80d50_ensemble
# Out:
# ...
# Model:        h5m80d50_ensemble
# Signal dir:   signals_h5ensemble
# Date range:   20260815 -> 20260821
# Files found:  4
# ...
#
# [1/4] 20260817  signals_20260817.csv
#     rows=6 updated=0 appended=6
#
# [2/4] 20260818  signals_20260818.csv
#     rows=6 updated=0 appended=6
#
# [3/4] 20260819  signals_20260819.csv
#     rows=7 updated=0 appended=7
#
# [4/4] 20260820  signals_20260820.csv
#     rows=5 updated=0 appended=5
#
# ...
# Files processed: 4
# Source rows:     24
# Rows updated:    0
# Rows appended:   24
# Audit rows:      896
# Saved:           h5ensemble.csv
# ...

# %%
# %run fill_signals_targets.py --signals h5ensemble.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h5ensemble_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [progress] checked=500/896 sold=481 open_updated=14 unresolved=5
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=896 already_filled=0
# [result] newly_sold=877 open_updated=14 unresolved=5
# [write] h5ensemble_target.csv

# %%
# %run fill_signals_targets.py --signals h2dual.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h2dual_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=87 already_filled=0
# [result] newly_sold=78 open_updated=7 unresolved=2
# [write] h2dual_target.csv

# %%
# %run b4mkt-new.py --signal-file h5priority_target.csv
# Out:
# model,ts_code,signal_date,priority,buy,gain_price,cut_price
# h5m80d50_priority,000880.SZ,20260817,2,26.430,28.474,25.038
# h5m80d50_priority,301392.SZ,20260814,3,169.660,185.600,163.545
# h5m80d50_priority,688048.SH,20260814,3,315.740,345.405,304.359
# h5m80d50_priority,688503.SH,20260817,3,96.420,103.876,91.342
# h5m80d50_priority,002965.SZ,20260817,,34.120,36.759,32.323
