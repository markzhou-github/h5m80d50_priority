# %%
# test all_signals

# %%
# %run all_signals_model_priority_config.py --source-file "signals_h5ensemble/signals_20260810.csv"  \
--audit-file test.csv --start-date 20260809 --end-date 20260812 --model-name model_h5ensemble
# Out:
# Audit file saved: test.csv
# Source file: signals_h5ensemble/signals_20260810.csv
# Model name: model_h5ensemble
# Filtered source rows: 8
# Updated audit keys: 0
# Appended audit keys: 8
# Final audit rows: 14
# Source date range used: 20260810 to 20260810

# %%
# %run all_signals_model_priority_config.py \
--source-file "signals_h5ensemble/signals_20260810.csv"  \
--audit-file h5ensemble.csv \
--start-date 20260809 \
--end-date 20260812 \
--model-name model_h5ensemble
# Out:
# Audit file saved: test.csv
# Source file: signals_h5ensemble/signals_20260810.csv
# Model name: model_h5ensemble
# Filtered source rows: 8
# Updated audit keys: 8
# Appended audit keys: 0
# Final audit rows: 14
# Source date range used: 20260810 to 20260810

# %%
# %run all_signals_model_priority_config.py \
--audit-file h5priority.csv \
--start-date 20260701 \
--end-date 20260813 \
--model-name h5m80d50_priority
# Out:
# ================================================================================
# Model:        h5m80d50_priority
# Signal dir:   signals_h5priority
# Date range:   20260701 -> 20260813
# Files found:  32
# ================================================================================
#
# [1/32] 20260701  signals_h5m80d50_priority_20260701.csv
#     rows=4 updated=0 appended=4
#
# [2/32] 20260702  signals_h5m80d50_priority_20260702.csv
#     rows=3 updated=0 appended=3
#
# [3/32] 20260703  signals_h5m80d50_priority_20260703.csv
#     rows=3 updated=0 appended=3
#
# [4/32] 20260706  signals_h5m80d50_priority_20260706.csv
#     rows=3 updated=0 appended=3
#
# [5/32] 20260707  signals_h5m80d50_priority_20260707.csv
#     rows=4 updated=0 appended=4
#
# [6/32] 20260708  signals_h5m80d50_priority_20260708.csv
#     rows=3 updated=0 appended=3
#
# [7/32] 20260709  signals_h5m80d50_priority_20260709.csv
#     rows=3 updated=0 appended=3
#
# [8/32] 20260710  signals_h5m80d50_priority_20260710.csv
#     rows=4 updated=0 appended=4
#
# [9/32] 20260713  signals_h5m80d50_priority_20260713.csv
#     rows=3 updated=0 appended=3
#
# [10/32] 20260714  signals_h5m80d50_priority_20260714.csv
#     rows=3 updated=0 appended=3
#
# [11/32] 20260715  signals_h5m80d50_priority_20260715.csv
#     rows=3 updated=0 appended=3
#
# [12/32] 20260716  signals_h5m80d50_priority_20260716.csv
#     rows=3 updated=0 appended=3
#
# [13/32] 20260717  signals_h5m80d50_priority_20260717.csv
#     rows=3 updated=0 appended=3
#
# [14/32] 20260720  signals_h5m80d50_priority_20260720.csv
#     rows=3 updated=0 appended=3
#
# [15/32] 20260721  signals_h5m80d50_priority_20260721.csv
#     rows=3 updated=0 appended=3
#
# [16/32] 20260722  signals_h5m80d50_priority_20260722.csv
#     rows=3 updated=0 appended=3
#
# [17/32] 20260723  signals_h5m80d50_priority_20260723.csv
#     rows=3 updated=0 appended=3
#
# [18/32] 20260724  signals_h5m80d50_priority_20260724.csv
#     rows=3 updated=3 appended=0
#
# [19/32] 20260727  signals_h5m80d50_priority_20260727.csv
#     rows=3 updated=3 appended=0
#
# [20/32] 20260728  signals_h5m80d50_priority_20260728.csv
#     rows=3 updated=3 appended=0
#
# [21/32] 20260729  signals_h5m80d50_priority_20260729.csv
#     rows=3 updated=3 appended=0
#
# [22/32] 20260730  signals_h5m80d50_priority_20260730.csv
#     rows=4 updated=4 appended=0
#
# [23/32] 20260731  signals_h5m80d50_priority_20260731.csv
#     rows=3 updated=3 appended=0
#
# [24/32] 20260803  signals_h5m80d50_priority_20260803.csv
#     rows=3 updated=3 appended=0
#
# [25/32] 20260804  signals_h5m80d50_priority_20260804.csv
#     rows=3 updated=3 appended=0
#
# [26/32] 20260805  signals_h5m80d50_priority_20260805.csv
#     rows=3 updated=3 appended=0
#
# [27/32] 20260806  signals_h5m80d50_priority_20260806.csv
#     rows=3 updated=3 appended=0
#
# [28/32] 20260807  signals_h5m80d50_priority_20260807.csv
#     rows=3 updated=3 appended=0
#
# [29/32] 20260810  signals_h5m80d50_priority_20260810.csv
#     rows=3 updated=3 appended=0
#
# [30/32] 20260811  signals_h5m80d50_priority_20260811.csv
#     rows=3 updated=3 appended=0
#
# [31/32] 20260812  signals_h5m80d50_priority_20260812.csv
#     rows=3 updated=0 appended=3
#
# [32/32] 20260813  signals_h5m80d50_priority_20260813.csv
#     rows=3 updated=0 appended=3
#
# ================================================================================
# Files processed: 32
# Source rows:     100
# Rows updated:    40
# Rows appended:   60
# Audit rows:      100
# Saved:           h5priority.csv
# ================================================================================

# %%
# %run fill_signals_targets.py --signals h5priority.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h5priority_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=100 already_filled=0
# [result] newly_sold=92 open_updated=8 unresolved=0
# [write] h5priority_target.csv

# %%
# %run all_signals_model_priority_config.py \
--audit-file h2dual.csv \
--start-date 20260701 \
--end-date 20260813 \
--model-name h2m80d50_dual
# Out:
# ================================================================================
# Model:        h2m80d50_dual
# Signal dir:   signals_h2dual
# Date range:   20260709 -> 20260813
# Files found:  13
# ================================================================================
# Audit file does not exist. A new file will be created: h2duel.csv
#
# [1/13] 20260724  signals_20260724.csv
#     rows=0 updated=0 appended=0
#
# [2/13] 20260727  signals_20260727.csv
#     rows=2 updated=0 appended=2
#
# [3/13] 20260728  signals_20260728.csv
#     rows=0 updated=0 appended=0
#
# [4/13] 20260729  signals_20260729.csv
#     rows=0 updated=0 appended=0
#
# [5/13] 20260730  signals_20260730.csv
#     rows=0 updated=0 appended=0
#
# [6/13] 20260731  signals_20260731.csv
#     rows=2 updated=0 appended=2
#
# [7/13] 20260803  signals_20260803.csv
#     rows=0 updated=0 appended=0
#
# [8/13] 20260804  signals_20260804.csv
#     rows=0 updated=0 appended=0
#
# [9/13] 20260805  signals_20260805.csv
#     rows=0 updated=0 appended=0
#
# [10/13] 20260806  signals_20260806.csv
#     rows=2 updated=0 appended=2
#
# [11/13] 20260807  signals_20260807.csv
#     rows=2 updated=0 appended=2
#
# [12/13] 20260810  signals_20260810.csv
#     rows=7 updated=0 appended=7
#
# [13/13] 20260811  signals_20260811.csv
#     rows=7 updated=0 appended=7
#
# ================================================================================
# Files processed: 13
# Source rows:     22
# Rows updated:    0
# Rows appended:   22
# Audit rows:      22
# Saved:           h2duel.csv
# ================================================================================

# %%
# %run fill_signals_targets.py --signals h2duel.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h2dual_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=22 already_filled=0
# [result] newly_sold=8 open_updated=7 unresolved=7
# [write] h2dual_target.csv

# %%
# %run all_signals_model_priority_config.py \
--audit-file h5ensemble.csv \
--start-date 20260709 \
--end-date 20260813 \
--model-name h5m80d50_ensemble
# Out:
# ================================================================================
# Model:        h5m80d50_ensemble
# Signal dir:   signals_h5ensemble
# Date range:   20260709 -> 20260813
# Files found:  13
# ================================================================================
# Audit file does not exist. A new file will be created: h5ensemble.csv
#
# [1/13] 20260724  signals_20260724.csv
#     rows=6 updated=0 appended=6
#
# [2/13] 20260727  signals_20260727.csv
#     rows=5 updated=0 appended=5
#
# [3/13] 20260728  signals_20260728.csv
#     rows=5 updated=0 appended=5
#
# [4/13] 20260729  signals_20260729.csv
#     rows=6 updated=0 appended=6
#
# [5/13] 20260730  signals_20260730.csv
#     rows=6 updated=0 appended=6
#
# [6/13] 20260731  signals_20260731.csv
#     rows=8 updated=0 appended=8
#
# [7/13] 20260803  signals_20260803.csv
#     rows=7 updated=0 appended=7
#
# [8/13] 20260804  signals_20260804.csv
#     rows=7 updated=0 appended=7
#
# [9/13] 20260805  signals_20260805.csv
#     rows=7 updated=0 appended=7
#
# [10/13] 20260806  signals_20260806.csv
#     rows=8 updated=0 appended=8
#
# [11/13] 20260807  signals_20260807.csv
#     rows=8 updated=0 appended=8
#
# [12/13] 20260810  signals_20260810.csv
#     rows=8 updated=0 appended=8
#
# [13/13] 20260811  signals_20260811.csv
#     rows=6 updated=0 appended=6
#
# ================================================================================
# Files processed: 13
# Source rows:     87
# Rows updated:    0
# Rows appended:   87
# Audit rows:      87
# Saved:           h5ensemble.csv
# ================================================================================

# %%
# %run fill_signals_targets.py --signals h5ensemble.csv \
--stock-dir processed/daily/merged \
--benchmark processed/index/csi1500_custom_index.csv \
--out h5ensemble_target.csv \
--benchmark-return-col csi1500_ew_close_ret
# Out:
# [benchmark] return_column=csi1500_ew_close_ret
# [rows] total=87 already_filled=0
# [result] newly_sold=67 open_updated=14 unresolved=6
# [write] h5ensemble_target.csv
