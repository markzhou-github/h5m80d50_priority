# %%
# %run h5m80d50_priority/generate_signals_range.py --input processed/train_v5b/train_v5b.parquet  \
--out-dir signals_h5priority \
--start-date 20260701 \
--end-date 20260815
# Out:
# [load] processed/train_v5b/train_v5b.parquet 20260701 ~ 20260815
# [rows] 47106 dates=33 date_min=20260701 date_max=20260814
# [predict] start
# /Users/mark_zhou/Downloads/01-Stock/h5m80d50/h5m80d50_priority/generate_signals.py:186: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   out["vote3_top3"] = out["vote3_top3"].fillna(False).astype(bool)
# /Users/mark_zhou/Downloads/01-Stock/h5m80d50/h5m80d50_priority/generate_signals.py:200: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   out["vote4_strict_top3"] = out["vote4_strict_top3"].fillna(False).astype(bool)
# [1/33] 20260701 rows=1425 trade=2 watchlist=2
# [2/33] 20260702 rows=1425 trade=1 watchlist=2
# [3/33] 20260703 rows=1425 trade=2 watchlist=1
# [4/33] 20260706 rows=1425 trade=0 watchlist=3
# [5/33] 20260707 rows=1426 trade=1 watchlist=3
# [6/33] 20260708 rows=1426 trade=1 watchlist=2
# [7/33] 20260709 rows=1425 trade=1 watchlist=2
# [8/33] 20260710 rows=1426 trade=2 watchlist=2
# [9/33] 20260713 rows=1426 trade=0 watchlist=3
# [10/33] 20260714 rows=1427 trade=1 watchlist=2
# [11/33] 20260715 rows=1427 trade=2 watchlist=1
# [12/33] 20260716 rows=1427 trade=1 watchlist=2
# [13/33] 20260717 rows=1427 trade=2 watchlist=1
# [14/33] 20260720 rows=1427 trade=1 watchlist=2
# [15/33] 20260721 rows=1427 trade=1 watchlist=2
# [16/33] 20260722 rows=1427 trade=2 watchlist=1
# [17/33] 20260723 rows=1427 trade=2 watchlist=1
# [18/33] 20260724 rows=1427 trade=1 watchlist=2
# [19/33] 20260727 rows=1428 trade=0 watchlist=3
# [20/33] 20260728 rows=1428 trade=0 watchlist=3
# [21/33] 20260729 rows=1428 trade=2 watchlist=1
# [22/33] 20260730 rows=1429 trade=1 watchlist=3
# [23/33] 20260731 rows=1429 trade=1 watchlist=2
# [24/33] 20260803 rows=1429 trade=1 watchlist=2
# [25/33] 20260804 rows=1429 trade=0 watchlist=3
# [26/33] 20260805 rows=1429 trade=1 watchlist=2
# [27/33] 20260806 rows=1429 trade=2 watchlist=1
# [28/33] 20260807 rows=1429 trade=0 watchlist=3
# [29/33] 20260810 rows=1429 trade=2 watchlist=1
# [30/33] 20260811 rows=1429 trade=1 watchlist=2
# [31/33] 20260812 rows=1429 trade=1 watchlist=2
# [32/33] 20260813 rows=1430 trade=0 watchlist=3
# [33/33] 20260814 rows=1430 trade=3 watchlist=0
# [SAVE] signals_h5priority/range_generation_summary_20260701_20260814.csv

# %%
# %run h2m80d50_dual/generate_signals2.py --input processed/train_v5b/train_v5b.parquet  \
--out-dir signals_h2dual \
--start-date 20260701 \
--end-date 20260815
# Out:
# usage: generate_signals2.py [-h] --input INPUT [--trade-date TRADE_DATE]
#                             [--out-dir OUT_DIR] [--allow-missing-features]
#                             [--save-ranked]
#                             [--candidate-top-n CANDIDATE_TOP_N] [--skip-seed]
#                             [--skip-day-regime]
# generate_signals2.py: error: unrecognized arguments: --start-date 20260701 --end-date 20260815
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
