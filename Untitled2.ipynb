# %%
# %run h5m80d50_priority/generate_signals_range.py --input processed/train_v5b/train_v5b.parquet  \
--out-dir signals_h5priority \
--start-date 20260815 \
--end-date 20260821
# Out:
# [load] processed/train_v5b/train_v5b.parquet 20260815 ~ 20260821
# [rows] 5716 dates=4 date_min=20260817 date_max=20260820
# [predict] start
# /Users/mark_zhou/Downloads/01-Stock/h5m80d50/h5m80d50_priority/generate_signals.py:186: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   out["vote3_top3"] = out["vote3_top3"].fillna(False).astype(bool)
# /Users/mark_zhou/Downloads/01-Stock/h5m80d50/h5m80d50_priority/generate_signals.py:200: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   out["vote4_strict_top3"] = out["vote4_strict_top3"].fillna(False).astype(bool)
# [1/4] 20260817 rows=1430 trade=2 watchlist=1
# [2/4] 20260818 rows=1429 trade=0 watchlist=3
# [3/4] 20260819 rows=1429 trade=3 watchlist=0
# [4/4] 20260820 rows=1428 trade=3 watchlist=0
# [SAVE] signals_h5priority/range_generation_summary_20260817_20260820.csv

# %%
# %run h2m80d50_dual/generate_signals_range.py --input processed/train_v5b/train_v5b.parquet  \
--out-dir signals_h2dual \
--start-date 20260815 \
--end-date 20260821
# Out:
# [models] family=3 seed=5 day=label_broad_top5_tp_ge_3
# [load] processed/train_v5b/train_v5b.parquet 20260815 ~ 20260821
# [input] rows=5716 dates=4 date_min=20260817 date_max=20260820
# [SAVE] signals_h2dual/signals_20260817.csv rows=2
# [SAVE] signals_h2dual/signals_20260818.csv rows=6
# [SAVE] signals_h2dual/signals_20260819.csv rows=5
# [SAVE] signals_h2dual/signals_20260820.csv rows=4
# [SAVE] signals_h2dual/range_generation_summary_20260817_20260820.csv

# %%
# %run h5m80d50_ensemble/generate_signals_range.py --input processed/train_v5b/train_v5b.parquet  \
--out-dir signals_h5ensemble \
--start-date 20260815 \
--end-date 20260821
# Out:
# [load] processed/train_v5b/train_v5b.parquet 20260815 ~ 20260821
# [rows] 5716 dates=4 date_min=20260817 date_max=20260820
# [predict] family=F150
# [predict] family=C185
# [predict] family=F220
# [1/4] 20260817 universe=1430 signals=6 production=1
# [2/4] 20260818 universe=1429 signals=6 production=1
# [3/4] 20260819 universe=1429 signals=7 production=1
# [4/4] 20260820 universe=1428 signals=5 production=0
# [SAVE] signals_h5ensemble/range_generation_summary_20260817_20260820.csv

# %%
# %run notify_daily.py
# Out:
#       ts_code  priority     model  horizon  gain   cut
# 0   000880.SZ         2  priority        5  0.08 -0.05
# 1   688503.SH         3  priority        5  0.08 -0.05
# 2   002965.SZ         0  priority        5  0.08 -0.05
# 3   002081.SZ         1  ensemble        5  0.08 -0.05
# 4   603118.SH         3  ensemble        5  0.08 -0.05
# 5   603083.SH         3  ensemble        5  0.08 -0.05
# 6   688766.SH         3  ensemble        5  0.08 -0.05
# 7   600353.SH         2  ensemble        5  0.08 -0.05
# 8   688313.SH         3  ensemble        5  0.08 -0.05
# 9   301127.SZ         3      dual        2  0.08 -0.05
# 10  688048.SH         3      dual        2  0.08 -0.05
#      ts_code  priority     model  horizon  gain   cut
# 0  000880.SZ         2  priority        5  0.08 -0.05
# 1  688503.SH         3  priority        5  0.08 -0.05
# 2  002965.SZ         0  priority        5  0.08 -0.05
# priority:
#  20260817,H5M80D50
# ts_code,priority
# 000880.SZ,2
# 688503.SH,3
# 002965.SZ,0
#
# dual:
#  20260817,H2M80D50
# ts_code,priority
# 301127.SZ,3
# 688048.SH,3
#
# ensemble:
#  20260817,H5M80D50
# ts_code,priority
# 002081.SZ,1
# 603118.SH,3
# 603083.SH,3
# 688766.SH,3
# 600353.SH,2
# 688313.SH,3
#
# {'detail': '服务器内部错误'}
